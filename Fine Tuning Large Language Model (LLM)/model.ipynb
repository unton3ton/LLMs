# %% [markdown]
# # Installing Dependencies

# %%
# !pip install transformers datasets torch accelerate pandas
# Out:
# Requirement already satisfied: transformers in ./FINETUNINGLLM/lib/python3.10/site-packages (4.48.0)
# Requirement already satisfied: datasets in ./FINETUNINGLLM/lib/python3.10/site-packages (3.2.0)
# Requirement already satisfied: torch in ./FINETUNINGLLM/lib/python3.10/site-packages (2.5.1)
# Requirement already satisfied: accelerate in ./FINETUNINGLLM/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: pandas in ./FINETUNINGLLM/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: filelock in ./FINETUNINGLLM/lib/python3.10/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in ./FINETUNINGLLM/lib/python3.10/site-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in ./FINETUNINGLLM/lib/python3.10/site-packages (from transformers) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in ./FINETUNINGLLM/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in ./FINETUNINGLLM/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in ./FINETUNINGLLM/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in ./FINETUNINGLLM/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in ./FINETUNINGLLM/lib/python3.10/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in ./FINETUNINGLLM/lib/python3.10/site-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in ./FINETUNINGLLM/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in ./FINETUNINGLLM/lib/python3.10/site-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in ./FINETUNINGLLM/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in ./FINETUNINGLLM/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in ./FINETUNINGLLM/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in ./FINETUNINGLLM/lib/python3.10/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in ./FINETUNINGLLM/lib/python3.10/site-packages (from datasets) (3.11.11)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in ./FINETUNINGLLM/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./FINETUNINGLLM/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: psutil in ./FINETUNINGLLM/lib/python3.10/site-packages (from accelerate) (6.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./FINETUNINGLLM/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./FINETUNINGLLM/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./FINETUNINGLLM/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./FINETUNINGLLM/lib/python3.10/site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./FINETUNINGLLM/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./FINETUNINGLLM/lib/python3.10/site-packages (from aiohttp->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in ./FINETUNINGLLM/lib/python3.10/site-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./FINETUNINGLLM/lib/python3.10/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./FINETUNINGLLM/lib/python3.10/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in ./FINETUNINGLLM/lib/python3.10/site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./FINETUNINGLLM/lib/python3.10/site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: six>=1.5 in ./FINETUNINGLLM/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./FINETUNINGLLM/lib/python3.10/site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./FINETUNINGLLM/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./FINETUNINGLLM/lib/python3.10/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./FINETUNINGLLM/lib/python3.10/site-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in ./FINETUNINGLLM/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)

# %% [markdown]
# # Import Libraries

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from transformers import TrainingArguments, Trainer
from datasets import load_dataset

# %% [markdown]
# # Import Model

# %%
# Load pre-trained GPT-2 model and tokenizer
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# %% [markdown]
# # Importing and Processing Dataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set the pad_token for the tokenizer
tokenizer.pad_token = tokenizer.eos_token

# Load your dataset in a CSV file
dataset = load_dataset("csv", data_files="data.csv")

import pandas as pd
data = pd.read_csv('data.csv')
print(data.head())

# Split the dataset into training and validation sets
train_data = dataset["train"].select([i for i in range(len(dataset["train"])) if i % 10 != 0])  # Use 90% of the data for training
val_data = dataset["train"].select([i for i in range(len(dataset["train"])) if i % 10 == 0])  # Use 10% of the data for validation

# Tokenize the input and target sequences
def tokenize_function(examples):
    inputs = tokenizer(examples['Bad_Practices'], return_tensors='pt', padding='max_length', max_length=512, truncation=True)
    labels = tokenizer(examples['Good_Practices'], return_tensors='pt', padding='max_length', max_length=512, truncation=True)
    return {'input_ids': inputs['input_ids'], 'labels': labels['input_ids']}

# Apply tokenization to the datasets
train_data = train_data.map(tokenize_function, batched=True)
val_data = val_data.map(tokenize_function, batched=True)
# Out:
#                      Bad_Practices                      Good_Practices
# 0  <table alt=header>Title</table>   <table alt='header'>Title</table>
# 1                      <tr>Content                    <tr>Content</tr>
# 2    <h2 src='description'>Content  <h2 src='description'>Content</h2>
# 3                      <table>Link                 <table>Link</table>
# 4          <img src='description'>      <img src='description' alt=''>

# %% [markdown]
# # Train Model

# %%
# Define training arguments
training_args = TrainingArguments(
    output_dir='./model',
    overwrite_output_dir=True,
    num_train_epochs=0.5,
    per_device_train_batch_size=2,
    eval_strategy="steps",
    eval_steps=100,
    save_steps=500,
    logging_steps=100,
    logging_dir='./logs',
    report_to=None
)

# Create a Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_data,
    eval_dataset=val_data,
)

# Fine-tune the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='1510' max='1510' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1510/1510 05:41, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.019900</td>
#       <td>0.019064</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.019600</td>
#       <td>0.017813</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.018000</td>
#       <td>0.018170</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.018600</td>
#       <td>0.017858</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.018800</td>
#       <td>0.017333</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.018200</td>
#       <td>0.017137</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.017600</td>
#       <td>0.016685</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.017900</td>
#       <td>0.017640</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.018200</td>
#       <td>0.016867</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.017700</td>
#       <td>0.016806</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.017100</td>
#       <td>0.016637</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.017000</td>
#       <td>0.016440</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.016900</td>
#       <td>0.016443</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.017100</td>
#       <td>0.016367</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.016400</td>
#       <td>0.016377</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1510, training_loss=0.01792855885447256, metrics={'train_runtime': 341.7734, 'train_samples_per_second': 8.836, 'train_steps_per_second': 4.418, 'total_flos': 789101936640000.0, 'train_loss': 0.01792855885447256, 'epoch': 0.5})

# %% [markdown]
# # Save Model

# %%
trainer.save_model()

# %% [markdown]
# # Running Inference

# %%
# Inference Example
example_input = "<h1>Heading"
input_ids = tokenizer(example_input, return_tensors="pt")["input_ids"].to(device)
attention_mask = torch.ones(input_ids.shape, device=device)
output_ids = model.generate(input_ids, 
                            max_length=512, 
                            num_return_sequences=1, 
                            top_k=50, 
                            top_p=0.95, 
                            attention_mask=attention_mask,
                            do_sample=True,)

# Decode and print the corrected HTML code
decoded_output = tokenizer.decode(output_ids[0], skip_special_tokens=True)
print("Original HTML code:", example_input)
print("Corrected HTML code:", decoded_output)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Original HTML code: <h1>Heading
# Corrected HTML code: <h1>Heading style</h1>

# %%
# Inference Example
example_input = "</table>"
input_ids = tokenizer(example_input, return_tensors="pt")["input_ids"].to(device)
attention_mask = torch.ones(input_ids.shape, device=device)
output_ids = model.generate(input_ids, 
                            max_length=512, 
                            num_return_sequences=1, 
                            top_k=50, 
                            top_p=0.95, 
                            attention_mask=attention_mask,
                            do_sample=True,)

# Decode and print the corrected HTML code
decoded_output = tokenizer.decode(output_ids[0], skip_special_tokens=True)
print("Original HTML code:", example_input)
print("Corrected HTML code:", decoded_output)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Original HTML code: </table>
# Corrected HTML code: </table>Hello</table>
